# %%
5<9
# Out:
# True

# %%
8<1
# Out:
# False

# %%
myAnimationCaracter=input("gir")
# Out:
# gir elsa

# %%
if myAnimationCaracter=="batman":
   print("BATMAN")
elif myAnimationCaracter=="McQueen":
   print(" şimşek McQueen")
else:
   print(":(")
# Out:
# :(

# %%
print("selam sana imparator")
# Out:
# selam sana imparator

# %%
my_age=21
if my_age ==21:
   print("Fatihin İstanbulu fethettiği yaştasın")
elif my_age <21 and my_age>10:
   print("10-age-20")
else:
    print("çok büyüküsn")
# Out:
# Fatihin İstanbulu fethettiği yaştasın
