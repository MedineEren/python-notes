# %%
#key-value pairing

# %%
fruit_list=["banana", "apple"]

# %%
calorie_list=[100, 150]

# %%
fitness_dictionary={"banana":100, "apple":150}

# %%
type(fitness_dictionary)
# Out:
# dict

# %%
fitness_dictionary["banana"]
# Out:
# 100

# %%
fitness_dictionary["apple"]
# Out:
# 150

# %%
fitness_dictionary.keys()
# Out:
# dict_keys(['banana', 'apple'])

# %%
fitness_dictionary.values()
# Out:
# dict_values([100, 150])

# %%
type(fitness_dictionary.values())
# Out:
# dict_values

# %%
list(fitness_dictionary.values())
# Out:
# [100, 150]

# %%
fitness_dictionary["melon"]=300

# %%
fitness_dictionary
# Out:
# {'banana': 100, 'apple': 150, 'melon': 300}

# %%
my_dictionary={"key1":221, "key2":365, "key3":121, "key4":[897, 3, 89]}

# %%
my_dictionary["key4"] #4.keyin valuesini verir
# Out:
# [897, 3, 89]

# %%
my_dictionary["key4"][1] #4th key in 1st index
# Out:
# 3

# %%
last_dictionary={"k1":8, "k2":9, "k3":12, "k4":[10,20,30,40], "k5":{"a":80, "b":90}}

# %%
last_dictionary["k4"][2]
# Out:
# 30

# %%
last_dictionary["k5"]["b"]
# Out:
# 90

# %% [markdown]
# SET

# %%
#UNİQUE ELEMENTS, UNORDERED {} ile gösterilir

# %%
myList=(10, 20, 30, 40,40, 10, 10 ,20, 30, 50 )

# %%
len(myList)
# Out:
# 10

# %%
mySet={10, 20, 30, 40,40, 10, 10 ,20, 30, 50}

# %%
len(mySet)  #sette her değer yanşızca bir defa alınabilir
# Out:
# 5

# %%
mySet  #we are looking here
# Out:
# {10, 20, 30, 40, 50}

# %%
mySet.add(10)

# %%
mySet  #bir şey değişmedi çünkü 10 zaten vardı
# Out:
# {10, 20, 30, 40, 50}

# %%
mySet.add(60)

# %%
mySet #artık setimize 60 eklendi çünkü 60 daha önce yoktu
# Out:
# {10, 20, 30, 40, 50, 60}

# %%
#.union birleşitrebilir

# %%
mySet2={50, 60,70,80,90}

# %%
mySet.union(mySet2)  #mesela şuanda 50 ve 60 ı iki defa yazmaddı
# Out:
# {10, 20, 30, 40, 50, 60, 70, 80, 90}

# %%
mySet.intersection(mySet2) #kesişimleri
# Out:
# {50, 60}

# %%
countryList=("tr","de","fr","fr","de","tr","nl", "usa","tr","fr","nl")  #satış yapılan ülkeler

# %%
len(countryList)
# Out:
# 11

# %%
set(countryList)
# Out:
# {'de', 'fr', 'nl', 'tr', 'usa'}

# %%
len(set(countryList))   #kaç ülkeye satıış yaptığı
# Out:
# 5

# %%
emptyList=[]

# %%
emptyList.append(10)

# %%
emptyList.append(20)

# %%
emptyList.append(30)

# %%
emptyList.append(40)

# %%
emptyList
# Out:
# [10, 20, 30, 40]

# %%
emptyDictionary=dict()

# %%
emptyDictionary["a"]=10

# %%
emptyDictionary["b"]=20

# %%
emptyDictionary
# Out:
# {'a': 10, 'b': 20}

# %% [markdown]
# TUUPLE

# %%
myTuple=(14,"v","i",17)

# %%
type(myTuple)
# Out:
# tuple

# %%
# dediğimizde sadec iki fonksiyon çıkıyor myTuple.  İNDEX AND COUNT

# %%
#immutability     değiştirilemez

# %%
myTuple.count("v")
# Out:
# 1

# %%
myTuple.index("v")
# Out:
# 1
