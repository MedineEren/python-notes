# %%
7+1
# Out:
# 8

# %%
print("medoş")
# Out:
# medoş

# %% [markdown]
# VARİABLE

# %%
age=20

# %%
age+4
# Out:
# 24

# %%
age/2
# Out:
# 10.0

# %%
#DATA TYPE yorum satırı

# %%
type(age)
# Out:
# int

# %%
type("medos")
# Out:
# str

# %%
10%3 #kalanını gösterir
# Out:
# 1

# %% [markdown]
# STRING

# %%
print("hello world")
# Out:
# hello world

# %%
name="medine"

# %%
type(name)
# Out:
# str

# %%
name.capitalize() #ilk harfi büyüttü
# Out:
# 'Medine'

# %%
name.casefold() #
# Out:
# 'medine'

# %%
name.islower()
# Out:
# True

# %%
barcode = "TR58952345"

# %%
barcode[1]
# Out:
# 'R'

# %%
barcode[5]
# Out:
# '5'

# %% [markdown]
# SLICING

# %%
# barcode[starting index: stopping index: stepping size]

# %%
barcode[3::] #3.indexten başlıyor
# Out:
# '8952345'

# %%
barcode [:5:] #5. indexte dur
# Out:
# 'TR589'

# %%
barcode [::2] #ikişer ikişer atla
# Out:
# 'T5924'

# %% [markdown]
# LIST

# %%
floatlist= [21.8586, 84.003 , 3.67 ,38.01]

# %%
type(floatlist)
# Out:
# list

# %%
type(floatlist[1])
# Out:
# float

# %%
namelist = ["medine" , "ertugrul" , "ayse", "fatma"]

# %%
type(namelist)
# Out:
# list

# %%
mixedlist= [34.611 , "atil" , "notebook" , 89 ,'A' , 289]

# %%
type(mixedlist)
# Out:
# list

# %%
type(mixedlist[0])  #0. type of index
# Out:
# float

# %%
type(mixedlist[1])  #1. type of index
# Out:
# str

# %%
type(mixedlist[3])   #3. type of index
# Out:
# int

# %%
list1=[10, 20, 30]

# %%
list2=[40, 50, 60]

# %%
list1+ list2
# Out:
# [10, 20, 30, 40, 50, 60]

# %%
list1*2   #list1 i 2 defa yaz demek
# Out:
# [10, 20, 30, 10, 20, 30]

# %%
myNestedList= [ 10, 20, "atil", [30, 40, 41]]

# %%
myNestedList [0]
# Out:
# 10

# %%
myNestedList [2]
# Out:
# 'atil'

# %%
myNestedList [3]
# Out:
# [30, 40, 41]

# %%
x=myNestedList[0]

# %%
x
# Out:
# 10

# %%
smallList=myNestedList [3]

# %%
smallList
# Out:
# [30, 40, 41]

# %%
lastList=["a", "b", ["c", "d","e"],"f"]

# %%
lastList[0]
# Out:
# 'a'

# %%
lastList[2]
# Out:
# ['c', 'd', 'e']

# %%
#if it asks us for 'd', how do we show it?

# %%
lastList[2][1]
# Out:
# 'd'

# %%
firstList=[20, 21, 22, 23, 24 ,25, 26]

# %%
firstList[: :]
# Out:
# [20, 21, 22, 23, 24, 25, 26]

# %%
firstList[:4:] # stop at the index 4.
# Out:
# [20, 21, 22, 23]

# %%
firstList[::2] #write by jumping 2 at a time
# Out:
# [20, 22, 24, 26]
